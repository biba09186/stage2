# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rljGydpbFwPpvdR7kWQl")
project = rf.workspace("hiba-16eio").project("cin-wxdyl-jkgcy")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to cin-4 in yolov8:: 100%|███| 116/116 [00:02<00:00, 42.75it/s]

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="rljGydpbFwPpvdR7kWQl")
project = rf.workspace("hiba-16eio").project("cin-wxdyl-jkgcy")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # ou yolov8s.pt
model.train(data='cin-4/data.yaml', epochs=2)
